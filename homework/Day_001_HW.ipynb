# %% [markdown]
# 作業一
#
# 1.	你選的這組資料為何重要
# 所選的資料: Store Item Demand Forecasting Challenge
# 剛學python資料分析，所以選擇比較能了解的項目、資料。
# 資料中提供了1-10不同編號的商店，分別在2013-2017年間，銷售編號1-50不同項目的銷售量，藉由過去數據，去預測未來三個月不同地點店面的銷售額。
#
# 2.	資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 官方提供的train data(包括：日期、商店ID、商品ID、銷售量)
# https://www.kaggle.com/c/demand-forecasting-kernels-only/data
#
# 3. 蒐集而來的資料型態為何
# 連續數值資料，記錄方式為整數
#
#
# 4. 這組資料想解決的問題如何評估
# 資料提供了，每間商店過去五年在不同商品間的銷售額，可以用過去資料觀察，在同一時期同個商品的銷售額是否接近、產生什麼變化，再以相對應的時間預測未來銷售額的可能區間。
#
# 問題是預測未來三個月的銷售額，所得出來的答案是數值類，問題屬回歸問題，銷售額數值的異常點也需要列入參考，所以用MSE來做分析評估

# %% [markdown]
# 作業二
#
# 1.	核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 想透過數據提升業績，也就是提高載客率。因此需要觀察在某些條件狀況下，載客率是否有固定的變化。
#
# 假設時間、天氣、地點等因素會改變載客率，收集一定時間內的相關資料，觀察載客率是否有明確且固定的變化。
# 以較大時間區間來說，一年之中是否有某幾月載客率較高，再進一步去分析當月是否有特別或固定的事件。
# 而每天上下班時間是否為載客率最高時段、或是夜晚大眾運輸停駛後才是高峰。
# 天氣部分，在下雨、低溫、高溫載客率是否有明顯差異。
# 地點在車站、醫院、學校附近特定區域，叫車人次是否比其他地點來的多。
#
# 如果上述因素對載客率有明顯影響，那在符合高載客率的條件下可以多派車，不符合的條件下減少出勤車輛，配合數據做調整。
#
# 但如果以上因素改變效果不顯著，就必須在以用戶角度重新思考，譬如：車子本身的舒適度、外型，競爭對手的車資費用，等其他因素作為切入點重新檢視。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 所需要的時間要有日期、當日載客時間、載客地點、天氣。
# (1)	製作該車隊的叫車app，從用戶身上獲取相對應資料
# (2)	製作問卷，詢問一般用戶在特定情境下是否會增加叫車意願(若有註冊該車隊叫車app，需要另外排除避免重複計算)
# (3)	車隊車子裝設app，在接到單的時候就記錄下
#
# 3. 蒐集而來的資料型態為何
# 時間、日期為連續資料，記錄方式為字元
# 氣溫為連續資料，晴天或下雨為類別資料，記錄方式為字元
# 地點為類別資料，記錄方式為字元
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 問題是在不同情境下，載客率是否有變化，觀察重點在載客率，所以採用回歸分析，日常環境應該是穩定變動不大，所取資料的數值的異常點應該不會太多，避免異常點造成太多誤差，所以用MAE作分析評估。
#
#
#
# "剛開始學習python，在資料型態、該運用哪個驗證指標的部分，如果有錯誤，還請老師指正"

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
   
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae


def mean_squared_error(y,yi):
    """
    請完成這個 Function 後往下執行
    """
    mse=MSE= sum((abs(y - yi))**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 254.540
# The Mean absolute error is 12.396
